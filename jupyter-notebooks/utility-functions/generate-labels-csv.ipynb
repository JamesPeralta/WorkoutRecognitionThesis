# %% [markdown]
# # This file will convert the JSON labels that were generated from the GymCam annotation tool into a csv with the follow format:
#
# |file_name| video_file      | annotation_file | type   | reps |
# |---------|-----------------|-----------------|--------|------|
# |ohp5     | ./absolute/path | ./absolute/path | squats | 8    |

# %%
# GLOBAL VARIABLES
annotation_loc = "/Users/jamesperalta/Desktop/classes/CPSC-502/ResearchProposal/WorkoutRecognitionThesis/video_dataset/test/labels"
videos_loc = "/Users/jamesperalta/Desktop/classes/CPSC-502/ResearchProposal/WorkoutRecognitionThesis/video_dataset/test/"
output_loc = "/Users/jamesperalta/Desktop/classes/CPSC-502/ResearchProposal/WorkoutRecognitionThesis/video_dataset/"
output_filename = "test_annotations.csv"

# %% [markdown]
# ## Imports

# %%
import os
import re
import json
import pandas as pd

# %% [markdown]
# ## Generate the annotation file paths

# %%
# Helper functions
def extract_file_type(file_path):
    file_type = re.split("\d+_mp4_", file_path, maxsplit=1, flags=0)[0]
    return file_type.lower()

def extract_file_name(file_path):
    file_name = re.split("_mp4_", file_path, maxsplit=1, flags=0)[0]
    return file_name.lower()

# %%
annotation_files = os.listdir(annotation_loc)
annotation_files = sorted(annotation_files, key=extract_file_type )

parsed_json_list = []
for file in annotation_files:
    absolute_path = "{}/{}".format(annotation_loc, file)
    with open(absolute_path) as json_file:
        data = json.load(json_file)
        subject_block = data["subject_blocks"][0]
        events_block = subject_block["events"]
    
        # Retrieve the workout name
        workout_name = subject_block["name"].lower()

        # Retrieve the rep count
        rep_count = ""
        for event in events_block:
            if event["type"] == 2:
                rep_count = event["data"]
                break
                
        parsed_json_list.append({"file_name": extract_file_name(file), "annotation_file": absolute_path,
                                "workout_type": workout_name, "reps": rep_count })

annotation_df = pd.DataFrame(parsed_json_list)

# %%
annotation_df
# Out:
#    file_name                                    annotation_file workout_type  \
# 0      ohp15  /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp
# 1       ohp0  /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp
# 2      ohp20  /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp
# 3      ohp10  /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp
# 4      ohp30  /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp
# 5      ohp35  /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp
# 6       ohp5  /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp
# 7    squat30  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
# 8    squat10  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
# 9    squat39  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
# 10    squat0  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
# 11    squat5  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
# 12   squat35  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
# 13   squat15  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
# 14   squat25  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat
#
#       reps
# 0    9reps
# 1   10reps
# 2   10reps
# 3   10reps
# 4    9reps
# 5    9reps
# 6   11reps
# 7   10reps
# 8    8reps
# 9    8reps
# 10  10reps
# 11   9reps
# 12  10reps
# 13  10reps
# 14  10reps

# %% [markdown]
# ## Generate the video file paths

# %%
video_files = os.listdir(videos_loc)
video_type = ".mp4"
parsed_video_list = []
for video in video_files:
    if video.find(video_type) != -1:
        video_name = video.split(video_type)[0]
        video_location = "{}{}".format(videos_loc, video)
        parsed_video_list.append({"file_name": video_name, "video_file": video_location})

video_df = pd.DataFrame(parsed_video_list)

# %%
video_df
# Out:
#    file_name                                         video_file
# 0    squat10  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 1    squat39  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 2    squat15  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 3     squat5  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 4      ohp30  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 5      ohp35  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 6      ohp20  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 7     squat0  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 8       ohp0  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 9      ohp10  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 10      ohp5  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 11     ohp15  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 12   squat25  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 13   squat30  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 14   squat35  /Users/jamesperalta/Desktop/classes/CPSC-502/R...

# %% [markdown]
# ## Report videos with missing labels

# %%
# Left join video files with annotion files
# video_df['file_name'] = video_df['file_name'].astype(object)
# annotation_df['file_name'] = annotation_df['file_name'].astype(object)

final_result = pd.merge(video_df, annotation_df, on="file_name", sort=True)
final_result
# Out:
#    file_name                                         video_file  \
# 0       ohp0  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 1      ohp10  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 2      ohp15  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 3      ohp20  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 4      ohp30  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 5      ohp35  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 6       ohp5  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 7     squat0  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 8    squat10  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 9    squat15  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 10   squat25  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 11   squat30  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 12   squat35  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 13   squat39  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
# 14    squat5  /Users/jamesperalta/Desktop/classes/CPSC-502/R...
#
#                                       annotation_file workout_type    reps
# 0   /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp  10reps
# 1   /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp  10reps
# 2   /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp   9reps
# 3   /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp  10reps
# 4   /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp   9reps
# 5   /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp   9reps
# 6   /Users/jamesperalta/Desktop/classes/CPSC-502/R...          ohp  11reps
# 7   /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat  10reps
# 8   /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat   8reps
# 9   /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat  10reps
# 10  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat  10reps
# 11  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat  10reps
# 12  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat  10reps
# 13  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat   8reps
# 14  /Users/jamesperalta/Desktop/classes/CPSC-502/R...        squat   9reps

# %% [markdown]
# ## Store the CSV

# %%
final_result.to_csv("{}{}".format(output_loc, output_filename), index=False)

# %% [markdown]
# ## Check how many files are missing annotations

# %%
# final_result = final_result.append([{"file_name": "YO", "video_file": "/here/bro", "annotation_file": None, "workout_type": None, "reps":  None}])

# %%
files_no_annotation = final_result["annotation_file"].isna().sum()
print("There is {} video(s) with no annotations".format(files_no_annotation))
# Out:
# There is 0 video(s) with no annotations

# %%
final_result.loc[final_result["annotation_file"].isna()]
# Out:
# Empty DataFrame
# Columns: [file_name, video_file, annotation_file, workout_type, reps]
# Index: []
